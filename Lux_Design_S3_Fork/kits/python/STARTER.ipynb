# %%
# !python --version
# ! mkdir agent
# ! cp -r /kaggle/input/lux-ai-season-3/lux agent
# !pip install --upgrade luxai-s3

# !python --version
# !dir
# !luxai-s3 --help

# %%
import datetime
timestamp = datetime.datetime.now().strftime("%m%d%Y_%H%M%S")
replay_filename = f"outputs/replay_{timestamp}.html"
submission_filename = f"outputs/submission_{timestamp}.tar.gz"
print(replay_filename)
print(submission_filename)

# !luxai-s3 main.py main.py --output={replay_filename}
# Out:
# outputs/replay_02132025_215607.html
# outputs/submission_02132025_215607.tar.gz
# player_0, main.py: 0
#
# player_1, main.py: 0
#
# player_0, main.py: 1
#
# player_1, main.py: 1
#
# player_0, main.py: 2
#
# player_1, main.py: 2
#
# player_0, main.py: 3
#
# player_1, main.py: 3
#
# player_0, main.py: 4
#
# player_1, main.py: 4
#
# player_1, main.py: 5
#
# player_0, main.py: 5
#
# player_0, main.py: 6
#
# player_1, main.py: 6
#
# player_0, main.py: 7
#
# player_1, main.py: 7
#
# player_0, main.py: 8
#
# player_1, main.py: 8
#
# player_1, main.py: 9
#
# player_0, main.py: 9
#
# player_0, main.py: 10
#
# player_1, main.py: 10
#
# player_0, main.py: 11
#
# player_1, main.py: 11
#
# player_0, main.py: 12
#
# player_1, main.py: 12
#
# player_0, main.py: 13
#
# player_1, main.py: 13
#
# player_0, main.py: 14
#
# player_1, main.py: 14
#
# player_0, main.py: 15
#
# player_1, main.py: 15
#
# player_0, main.py: 16
#
# player_1, main.py: 16
#
# player_0, main.py: 17
#
# player_1, main.py: 17
#
# ...

# %%
# !tar --exclude="old/*" --exclude="outputs/*" -czf {submission_filename} .

# %%
# import IPython # load the HTML replay
# IPython.display.HTML(filename=replay_filename)
